# %%
# Using NLTK package as a toolkit for working with NLP in Python. 
# It provides various text processing libraries with a lot of test datasets.
import nltk
#nltk.download()

# Using the nltk.translate packages IBMModel1, Alignment and IBMModel1 for testing the translation between 2 languages corpus using IBM model 1.
from nltk.translate import AlignedSent, Alignment, IBMModel1

# Defaultdict is a sub-class of the dictionary class that returns a dictionary-like object.
# Using it for for making higher dimensional dictionaries.
from collections import defaultdict

import json # Extracting data from the .json files

source_language = 'ar' # The source language tag for foreign language.
translation_language = 'tr' # The translation language tag for English language.
FILE = 'ar_tr_pair_small.json' #data file with the translations
iterations_num = 2 # Number of iterations to run the EM algorithm.

# %% [markdown]
# # Function which takes an array containing pair(s) of sentences of a foreign & it's equivalent in English sentence as a parameter.
#
# ### Returning a defaultdict with tags for each word as either 'f' foreign word or 'e' English word.

# %%
def word_tag(corpus):
    corpus_words = defaultdict(set)
    for x in corpus:
        for y in x:
            words = x[y].split()
            for word in words:
                corpus_words[y].add(word)
    return corpus_words

# %% [markdown]
# # Function for training the model with EM algorithm with a specified number of iterations

# %%
def ibm1_EM(word_tags):
    
    sentence_pair = word_tag(word_tags) # Variable containing the pair of sentences (source & translation) with tags. 
    s_total = {} # Initializing an array for s_total.
    
    # Initializing required dictionaries.
    for word in sentence_pair[source_language]:
        s_total[word] = 0.0
    
    
    # Initialize t(e|f) uniformly.
    uniformly_dict = defaultdict(dict) # Creating a variable for the dictionary.
    for word_source in sentence_pair[source_language]: # for loop which runs over all words with tags as 'ar'.
        for word_translation in sentence_pair[translation_language]: # for loop which runs over all words with tags as 'tr'.
            uniformly_dict[word_source][word_translation] = 1 / len(sentence_pair[source_language]) # The transition_probabilities to 1/(length of the sentence in the source language).
    init_prob = uniformly_dict # The initial probability.
    iterations = 1 # Starting the iteration as 0.
    
    
    # While not converged do:
    while iterations <= iterations_num:
        current_prob = init_prob # A variable containing the initial probability.
        count = defaultdict(dict) # Creating a count variable containing a dictionary for all e and f values.
        total = defaultdict(dict) # Creating a total variable containing a dictionary for all f values.

        # Initializing count:
        # Nested for loop which runs over all words in both Arabic and Turkish languages and assigning their weight as 0.
        for word_source in sentence_pair[source_language]:
            for word_translation in sentence_pair[translation_language]:
                count[word_source][word_translation] = 0 # Assigning the weight of all words as 0.

        # Initializing total:
        # for loop which runs over all words in Turkish language and assigning their weight as 0.
        for word in sentence_pair[translation_language]:
            total[word] = 0 # Assigning the weight of all words in the Turkish language as 0.


        # For all sentence pair (e|f) do:
        # Compute normalization:
        print("Iteration ", "(", iterations, ")")
        for (es, fs) in [(pair[source_language].split(), pair[translation_language].split()) for pair in word_tags]:
            for e in es:  # For all words e in es do:
                s_total[e] = 0 # Intitialize s_total as 0.
                for f in fs: # For all words f in fs do:
                    s_total[e] += current_prob[e][f] # Updating the initial probability.
            print("s-total(e):: ", "ar:",es, "||", "tr:", fs, "==> ", s_total[e]) # Printing s-total(e).
            
                    

            # Collect counts:
            for e in es: # For all words e in e do:
                for f in fs: # For all words f in f do:
                    count[e][f] += (current_prob[e][f] / s_total[e])
                    total[f] += current_prob[e][f] / s_total[e]
            print("count(e|f):: ", "ar:",es, "||", "tr:", fs, "==> ", count[e][f]) # Printing count(e|f).
            print("total(f):: ", "ar:",es, "||", "tr:", fs, "==> ", total[f]) # Printing total(f).


        # Estimate probabilities:
        for f in sentence_pair[translation_language]: # For all Turkish words f do:
            for e in sentence_pair[source_language]: # For all Arabic words e do:
                current_prob[e][f] = count[e][f] / total[f]
                print("t(e|f):: ", "ar:",e ,"||", "tr:", f, "==> ", current_prob[e][f]) # Printing t(e|f).
                
        print("--------------------------------------------------------------------------")
        
        init_prob = current_prob # Updating the init_prob to the value of the current_prob.
        iterations += 1 # increament for the number of iteration inside the while loop.

    return current_prob # Returning the value of the current_prob.

# %% [markdown]
# # Function for acquiring the maximum translation probabilities as a dictionary

# %%
def maximum_prob(current_prob):
    prob_result = {} # Initializing an array for prob_result.
    
    source_key = current_prob.keys() # .keys() method returns a view object that displays a list of all the keys in the dictionary in order of insertion.
    translation_word = list(current_prob.values()) # A variable which stores the values of the dictionary inside a list.
    translation_key = translation_word[0].keys() # A variable which extract the keys of the dictionary starting from position 0.

    for word_source in source_key: # for loop which runs over all the keys titled as 'ar' Arabic language.
        max_prob = 0.0 # Initializing the max_prob variable as 0.
        max_translation_word = "" # A variable which stores the words of Turkish language.
        for word_translation in translation_key: # for loop which runs over all the keys titled as 'tr' Turkish language.
            if current_prob[word_source][word_translation] >= max_prob: # if condition which takes the pair of sentences with their current_prob and compare them with the max_prob.
                max_prob = current_prob[word_source][word_translation] # if the current_prob is bigger or equal to the max_prob, then assign the pair of sentences with their current_prob as max_prob.
                max_translation_word = word_translation  # A variable which stores the words of Turkish language.
        
        prob_result[word_source] = max_translation_word # Storing the words in an array from Turkish language with the most probability with their corresponding from Arabic language in the same position.

    return prob_result # Returning the maximum probability.

# %% [markdown]
# # Function for printing the alignment similarly to the IBM nltk model

# %%
def alignment(prob_result, word_tags):
    
    num = 1
    for x in word_tags: # for loop which runs over all the sentences.
        print("Source sentence", num, ":")
        print(x[source_language].split()) # Taking the Arabic sentence and split the words.
        print("Translation sentence", num, ":")
        print(x[translation_language].split()) # Taking the Turkish sentence and split the words.
        print("Alignment:")
        num += 1
        
        # Nested for loop for the alignment between each Araibc word with it's corresponding Turkish word.
        i = 0
        for word_source in x[source_language].split():
            j = 0
            for word_translation in x[translation_language].split():
                if word_translation == prob_result[word_source]: # if condition to match each Arabic word with it's corresponding Turkish word.
                    alignment = str(i) + "-" + str(j) + " "
                    print(alignment, end = "")
                    j = j + 1
                    break
                j = j + 1
            i = i + 1
        print("\n")

# %% [markdown]
# # Function for the translation from Turkish to English

# %%
def arabic_turkish():
    '''
    sentence_pair_tr = ['الطريق طويل', 'the road is long',
                        'الطريق كبير', 'the road is big',
                        'الطريق إلى الجبل طويل', 'the road to the mountain is long',
                        'أتيت إلى الجبل','I came to the mountain',
                        'تسلقت الجبل', 'I climbed the mountain']
    '''
    #parsing the json file and storing it in an object
    with open(FILE, 'r', encoding = 'utf-8') as f:
        corpus = json.load(f)
    
    # Calling the ibm1_EM function with passing the value obtained by the word_tag function.
    ibm_em_tr = ibm1_EM(corpus)
    
    # Calling the maximum_prob function with passing the value obtained by the ibm1_EM function.
    alignment_tr = maximum_prob(ibm_em_tr)
    
    # Calling the alignment function with passing the values obtained by the maximum_prob function and the object containing sentences with tags from word_tag function.
    alignment(alignment_tr, corpus)

# %% [markdown]
# # Main function

# %%
def main():
    arabic_turkish() # Translation from Turkish to English. (My Model)
    #nltk_ibm1() # Translation from Turkish to English. (NLTK IBM Model 1)

main()
# Out:
# Iteration  ( 1 )
# s-total(e)::  ar: ['بالنسبة', 'لي،', 'تبدأ', 'هذه', 'القصة', 'قبل', 'حوالي', '15', 'عاماً', 'مضت'] || tr: ['Benim', 'için', 'bu', 'hikaye', '15', 'sene', 'önce'] ==>  0.060344827586206906
# count(e|f)::  ar: ['بالنسبة', 'لي،', 'تبدأ', 'هذه', 'القصة', 'قبل', 'حوالي', '15', 'عاماً', 'مضت'] || tr: ['Benim', 'için', 'bu', 'hikaye', '15', 'sene', 'önce'] ==>  0.14285714285714282
# total(f)::  ar: ['بالنسبة', 'لي،', 'تبدأ', 'هذه', 'القصة', 'قبل', 'حوالي', '15', 'عاماً', 'مضت'] || tr: ['Benim', 'için', 'bu', 'hikaye', '15', 'sene', 'önce'] ==>  1.4285714285714282
# s-total(e)::  ar: ['عندما', 'كنت', 'طبيباً', 'نزيلاً', 'في', 'جامعة', 'شيكاغو'] || tr: ['Chicago', "Üniversitesi'nde", 'bir', 'darülacaze', 'doktoruyken', 'başladı'] ==>  0.05172413793103449
# count(e|f)::  ar: ['عندما', 'كنت', 'طبيباً', 'نزيلاً', 'في', 'جامعة', 'شيكاغو'] || tr: ['Chicago', "Üniversitesi'nde", 'bir', 'darülacaze', 'doktoruyken', 'başladı'] ==>  0.16666666666666666
# total(f)::  ar: ['عندما', 'كنت', 'طبيباً', 'نزيلاً', 'في', 'جامعة', 'شيكاغو'] || tr: ['Chicago', "Üniversitesi'nde", 'bir', 'darülacaze', 'doktoruyken', 'başladı'] ==>  1.1666666666666665
# s-total(e)::  ar: ['وكنت', 'أعتني', 'بالناس', 'الذين', 'على', 'وشك', 'الموت،', 'وأسرهم'] || tr: ['Ve', 'ben', "Chicago'nun", 'güney', 'tarafında,', 'ölmek', 'üzere', 'olan', 'insanlara'] ==>  0.07758620689655174
# count(e|f)::  ar: ['وكنت', 'أعتني', 'بالناس', 'الذين', 'على', 'وشك', 'الموت،', 'وأسرهم'] || tr: ['Ve', 'ben', "Chicago'nun", 'güney', 'tarafında,', 'ölmek', 'üzere', 'olan', 'insanlara'] ==>  0.11111111111111109
# total(f)::  ar: ['وكنت', 'أعتني', 'بالناس', 'الذين', 'على', 'وشك', 'الموت،', 'وأسرهم'] || tr: ['Ve', 'ben', "Chicago'nun", 'güney', 'tarafında,', 'ölmek', 'üzere', 'olan', 'insanlara'] ==>  0.8888888888888886
# s-total(e)::  ar: ['في', 'الجانب', 'الجنوبي', 'لشيكاغو'] || tr: ['ve', 'onların', 'ailelerine', 'bakıyordum'] ==>  0.034482758620689655
# count(e|f)::  ar: ['في', 'الجانب', 'الجنوبي', 'لشيكاغو'] || tr: ['ve', 'onların', 'ailelerine', 'bakıyordum'] ==>  0.25
# total(f)::  ar: ['في', 'الجانب', 'الجنوبي', 'لشيكاغو'] || tr: ['ve', 'onların', 'ailelerine', 'bakıyordum'] ==>  1.0
# s-total(e)::  ar: ['وكنت', 'أراقب', 'ما', 'يحدث', 'للناس', 'وأسرهم'] || tr: ['Ve', 'ölümcül', 'hastalıkları', 'süresince', 'bu', 'insanlara', 've', 'onların', 'ailelerine'] ==>  0.07758620689655174
# count(e|f)::  ar: ['وكنت', 'أراقب', 'ما', 'يحدث', 'للناس', 'وأسرهم'] || tr: ['Ve', 'ölümcül', 'hastalıkları', 'süresince', 'bu', 'insanlara', 've', 'onların', 'ailelerine'] ==>  0.11111111111111109
# total(f)::  ar: ['وكنت', 'أراقب', 'ما', 'يحدث', 'للناس', 'وأسرهم'] || tr: ['Ve', 'ölümcül', 'hastalıkları', 'süresince', 'bu', 'insanlara', 've', 'onların', 'ailelerine'] ==>  1.666666666666667
# s-total(e)::  ar: ['خلال', 'فترة', 'مرضهم', 'اللأخير'] || tr: ['ne', 'olduğunu', 'gözlemliyordum'] ==>  0.02586206896551724
# count(e|f)::  ar: ['خلال', 'فترة', 'مرضهم', 'اللأخير'] || tr: ['ne', 'olduğunu', 'gözlemliyordum'] ==>  0.3333333333333333
# total(f)::  ar: ['خلال', 'فترة', 'مرضهم', 'اللأخير'] || tr: ['ne', 'olduğunu', 'gözlemliyordum'] ==>  1.3333333333333333
# s-total(e)::  ar: ['وفي', 'مختبري،', 'كنت', 'أدرس', 'تأثير', 'الأرمل'] || tr: ['Laboratuvarımda,', 'sosyal', 'bilimlerde', 'çok', 'eski', 'bir', 'fikir', 'olan'] ==>  0.06896551724137932
# count(e|f)::  ar: ['وفي', 'مختبري،', 'كنت', 'أدرس', 'تأثير', 'الأرمل'] || tr: ['Laboratuvarımda,', 'sosyal', 'bilimlerde', 'çok', 'eski', 'bir', 'fikir', 'olan'] ==>  0.12499999999999997
# total(f)::  ar: ['وفي', 'مختبري،', 'كنت', 'أدرس', 'تأثير', 'الأرمل'] || tr: ['Laboratuvarımda,', 'sosyal', 'bilimlerde', 'çok', 'eski', 'bir', 'fikir', 'olan'] ==>  1.6388888888888886
# s-total(e)::  ar: ['الذي', 'هو', 'فكرة', 'قديمة', 'جداً', 'في', 'العلوم', 'الإجتماعية'] || tr: ['kökleri', '150', 'yıl', 'öncesine', 'kadar', 'giden'] ==>  0.05172413793103449
# count(e|f)::  ar: ['الذي', 'هو', 'فكرة', 'قديمة', 'جداً', 'في', 'العلوم', 'الإجتماعية'] || tr: ['kökleri', '150', 'yıl', 'öncesine', 'kadar', 'giden'] ==>  0.16666666666666666
# total(f)::  ar: ['الذي', 'هو', 'فكرة', 'قديمة', 'جداً', 'في', 'العلوم', 'الإجتماعية'] || tr: ['kökleri', '150', 'yıl', 'öncesine', 'kadar', 'giden'] ==>  1.3333333333333333
# s-total(e)::  ar: ['ترجع', 'لقبل', '150', 'عاماً'] || tr: ['ve', '"kırık', 'kalpten', 'ölmek"'] ==>  0.034482758620689655
# count(e|f)::  ar: ['ترجع', 'لقبل', '150', 'عاماً'] || tr: ['ve', '"kırık', 'kalpten', 'ölmek"'] ==>  0.25
# total(f)::  ar: ['ترجع', 'لقبل', '150', 'عاماً'] || tr: ['ve', '"kırık', 'kalpten', 'ölmek"'] ==>  1.0
# s-total(e)::  ar: ['ومعروفة', 'ب', '"', 'الموت', 'بسبب', 'إنكسار', 'القلب."', '"الحزن"'] || tr: ['olarak', 'bilinen', 'dul', 'kalma', 'etkisini', 'çalışıyordum'] ==>  0.05172413793103449
# count(e|f)::  ar: ['ومعروفة', 'ب', '"', 'الموت', 'بسبب', 'إنكسار', 'القلب."', '"الحزن"'] || tr: ['olarak', 'bilinen', 'dul', 'kalma', 'etkisini', 'çalışıyordum'] ==>  0.16666666666666666
# total(f)::  ar: ['ومعروفة', 'ب', '"', 'الموت', 'بسبب', 'إنكسار', 'القلب."', '"الحزن"'] || tr: ['olarak', 'bilinen', 'dul', 'kalma', 'etkisini', 'çalışıyordum'] ==>  1.3333333333333333
# s-total(e)::  ar: ['لذا،', 'فحينما', 'أموت،', 'تتضاعف', 'مخاطر', 'موت', 'زوجتي'] || tr: ['Buna', 'göre,', 'ben', 'öldüğümde,', 'örneğin', 'ilk', 'yılda'] ==>  0.060344827586206906
# count(e|f)::  ar: ['لذا،', 'فحينما', 'أموت،', 'تتضاعف', 'مخاطر', 'موت', 'زوجتي'] || tr: ['Buna', 'göre,', 'ben', 'öldüğümde,', 'örneğin', 'ilk', 'yılda'] ==>  0.14285714285714282
# total(f)::  ar: ['لذا،', 'فحينما', 'أموت،', 'تتضاعف', 'مخاطر', 'موت', 'زوجتي'] || tr: ['Buna', 'göre,', 'ben', 'öldüğümde,', 'örneğin', 'ilk', 'yılda'] ==>  0.9999999999999997
# s-total(e)::  ar: ['على', 'سبيل', 'المثال،', 'في', 'العام', 'الأول'] || tr: ['karımın', 'ölüm', 'riski', 'ikiye', 'katlanır'] ==>  0.04310344827586207
# count(e|f)::  ar: ['على', 'سبيل', 'المثال،', 'في', 'العام', 'الأول'] || tr: ['karımın', 'ölüm', 'riski', 'ikiye', 'katlanır'] ==>  0.19999999999999998
# total(f)::  ar: ['على', 'سبيل', 'المثال،', 'في', 'العام', 'الأول'] || tr: ['karımın', 'ölüm', 'riski', 'ikiye', 'katlanır'] ==>  1.2
# s-total(e)::  ar: ['وقد', 'شاركت', 'في', 'العناية', 'بمريض', 'محدد'] || tr: ['Ve', 'ben', 'özel', 'bir', 'hastanın,', 'akıl', 'hastalığından', 'ölmek', 'üzere'] ==>  0.07758620689655174
# count(e|f)::  ar: ['وقد', 'شاركت', 'في', 'العناية', 'بمريض', 'محدد'] || tr: ['Ve', 'ben', 'özel', 'bir', 'hastanın,', 'akıl', 'hastalığından', 'ölmek', 'üzere'] ==>  0.11111111111111109
# total(f)::  ar: ['وقد', 'شاركت', 'في', 'العناية', 'بمريض', 'محدد'] || tr: ['Ve', 'ben', 'özel', 'bir', 'hastanın,', 'akıl', 'hastalığından', 'ölmek', 'üzere'] ==>  1.5555555555555554
# s-total(e)::  ar: ['إمرأة', 'كانت', 'تموت', 'بسبب', 'الجنون'] || tr: ['olan', 'bir', 'kadının,', 'bakımıyla', 'ilgileniyordum'] ==>  0.04310344827586207
# count(e|f)::  ar: ['إمرأة', 'كانت', 'تموت', 'بسبب', 'الجنون'] || tr: ['olan', 'bir', 'kadının,', 'bakımıyla', 'ilgileniyordum'] ==>  0.19999999999999998
# total(f)::  ar: ['إمرأة', 'كانت', 'تموت', 'بسبب', 'الجنون'] || tr: ['olan', 'bir', 'kadının,', 'bakımıyla', 'ilgileniyordum'] ==>  0.9999999999999999
# s-total(e)::  ar: ['وفي', 'هذه', 'الحالة،', 'خلافاً', 'لهذين', 'الزوجين'] || tr: ['Ve,', 'bu', 'durumda,', 'bu', 'çiftten', 'ziyade'] ==>  0.05172413793103449
# count(e|f)::  ar: ['وفي', 'هذه', 'الحالة،', 'خلافاً', 'لهذين', 'الزوجين'] || tr: ['Ve,', 'bu', 'durumda,', 'bu', 'çiftten', 'ziyade'] ==>  0.16666666666666666
# total(f)::  ar: ['وفي', 'هذه', 'الحالة،', 'خلافاً', 'لهذين', 'الزوجين'] || tr: ['Ve,', 'bu', 'durumda,', 'bu', 'çiftten', 'ziyade'] ==>  0.9999999999999999
# s-total(e)::  ar: ['كانت', 'تعتني', 'بها'] || tr: ['ona', 'kendi', 'kızı'] ==>  0.02586206896551724
# count(e|f)::  ar: ['كانت', 'تعتني', 'بها'] || tr: ['ona', 'kendi', 'kızı'] ==>  0.3333333333333333
# total(f)::  ar: ['كانت', 'تعتني', 'بها'] || tr: ['ona', 'kendi', 'kızı'] ==>  1.0
# s-total(e)::  ar: ['بنتها'] || tr: ['bakıyordu'] ==>  0.008620689655172414
# count(e|f)::  ar: ['بنتها'] || tr: ['bakıyordu'] ==>  1.0
# total(f)::  ar: ['بنتها'] || tr: ['bakıyordu'] ==>  1.0
# s-total(e)::  ar: ['وكانت', 'الإبنة', 'مرهقة', 'من', 'العناية', 'بأمها'] || tr: ['Ve', 'kız', 'annesine', 'bakmaktan', 'yorgun', 'düşmüştü'] ==>  0.05172413793103449
# count(e|f)::  ar: ['وكانت', 'الإبنة', 'مرهقة', 'من', 'العناية', 'بأمها'] || tr: ['Ve', 'kız', 'annesine', 'bakmaktan', 'yorgun', 'düşmüştü'] ==>  0.16666666666666666
# total(f)::  ar: ['وكانت', 'الإبنة', 'مرهقة', 'من', 'العناية', 'بأمها'] || tr: ['Ve', 'kız', 'annesine', 'bakmaktan', 'yorgun', 'düşmüştü'] ==>  0.9999999999999999
# s-total(e)::  ar: ['وكان', 'زوج', 'الإبنة'] || tr: ['Ve', 'kızın', 'kocası', 'da'] ==>  0.034482758620689655
# count(e|f)::  ar: ['وكان', 'زوج', 'الإبنة'] || tr: ['Ve', 'kızın', 'kocası', 'da'] ==>  0.25
# total(f)::  ar: ['وكان', 'زوج', 'الإبنة'] || tr: ['Ve', 'kızın', 'kocası', 'da'] ==>  0.75
# s-total(e)::  ar: ['كذلك', 'قد', 'تعب'] || tr: ['karısının', 'tükenmişliğinden'] ==>  0.017241379310344827
# count(e|f)::  ar: ['كذلك', 'قد', 'تعب'] || tr: ['karısının', 'tükenmişliğinden'] ==>  0.5
# total(f)::  ar: ['كذلك', 'قد', 'تعب'] || tr: ['karısının', 'tükenmişliğinden'] ==>  1.5
# s-total(e)::  ar: ['من', 'إرهاق', 'زوجته'] || tr: ['dolayı', 'hastalanmıştı'] ==>  0.017241379310344827
# count(e|f)::  ar: ['من', 'إرهاق', 'زوجته'] || tr: ['dolayı', 'hastalanmıştı'] ==>  0.5
# total(f)::  ar: ['من', 'إرهاق', 'زوجته'] || tr: ['dolayı', 'hastalanmıştı'] ==>  1.5
# s-total(e)::  ar: ['وكنت', 'أقود', 'السيارة', 'إلى', 'المنزل', 'في', 'أحد', 'الأيام'] || tr: ['Ve', 'ben', 'bir', 'gün', 'eve', 'giderken'] ==>  0.05172413793103449
# count(e|f)::  ar: ['وكنت', 'أقود', 'السيارة', 'إلى', 'المنزل', 'في', 'أحد', 'الأيام'] || tr: ['Ve', 'ben', 'bir', 'gün', 'eve', 'giderken'] ==>  0.16666666666666666
# total(f)::  ar: ['وكنت', 'أقود', 'السيارة', 'إلى', 'المنزل', 'في', 'أحد', 'الأيام'] || tr: ['Ve', 'ben', 'bir', 'gün', 'eve', 'giderken'] ==>  1.3333333333333333
# s-total(e)::  ar: ['وتلقيت', 'مكالمة', 'من', 'صديق', 'الزوج'] || tr: ['kocasının', 'arkadaşından', 'bir', 'telefon', 'geldi', 'bana'] ==>  0.05172413793103449
# count(e|f)::  ar: ['وتلقيت', 'مكالمة', 'من', 'صديق', 'الزوج'] || tr: ['kocasının', 'arkadaşından', 'bir', 'telefon', 'geldi', 'bana'] ==>  0.16666666666666666
# total(f)::  ar: ['وتلقيت', 'مكالمة', 'من', 'صديق', 'الزوج'] || tr: ['kocasının', 'arkadaşından', 'bir', 'telefon', 'geldi', 'bana'] ==>  0.8333333333333333
# s-total(e)::  ar: ['إتصل', 'بي', 'لأنه', 'كان', 'محبطاً'] || tr: ['arkadaşına', 'olanlardan', 'dolayı'] ==>  0.02586206896551724
# count(e|f)::  ar: ['إتصل', 'بي', 'لأنه', 'كان', 'محبطاً'] || tr: ['arkadaşına', 'olanlardan', 'dolayı'] ==>  0.3333333333333333
# total(f)::  ar: ['إتصل', 'بي', 'لأنه', 'كان', 'محبطاً'] || tr: ['arkadaşına', 'olanlardan', 'dolayı'] ==>  3.166666666666667
# s-total(e)::  ar: ['لما', 'يجري', 'لصديقه'] || tr: ['neşesinin', 'kaçtığından', 'söz', 'ediyordu'] ==>  0.034482758620689655
# count(e|f)::  ar: ['لما', 'يجري', 'لصديقه'] || tr: ['neşesinin', 'kaçtığından', 'söz', 'ediyordu'] ==>  0.25
# total(f)::  ar: ['لما', 'يجري', 'لصديقه'] || tr: ['neşesinin', 'kaçtığından', 'söz', 'ediyordu'] ==>  0.75
# t(e|f)::  ar: تموت || tr: da ==>  0.0
# t(e|f)::  ar: طبيباً || tr: da ==>  0.0
# t(e|f)::  ar: 150 || tr: da ==>  0.0
# t(e|f)::  ar: إلى || tr: da ==>  0.0
# t(e|f)::  ar: وتلقيت || tr: da ==>  0.0
# t(e|f)::  ar: أحد || tr: da ==>  0.0
# t(e|f)::  ar: الإجتماعية || tr: da ==>  0.0
# t(e|f)::  ar: وأسرهم || tr: da ==>  0.0
# t(e|f)::  ar: 15 || tr: da ==>  0.0
# t(e|f)::  ar: كنت || tr: da ==>  0.0
# t(e|f)::  ar: القلب." || tr: da ==>  0.0
# t(e|f)::  ar: العام || tr: da ==>  0.0
# t(e|f)::  ar: الذي || tr: da ==>  0.0
# t(e|f)::  ar: نزيلاً || tr: da ==>  0.0
# t(e|f)::  ar: الإبنة || tr: da ==>  0.3333333333333333
# t(e|f)::  ar: تعب || tr: da ==>  0.0
# t(e|f)::  ar: زوجته || tr: da ==>  0.0
# t(e|f)::  ar: كانت || tr: da ==>  0.0
# t(e|f)::  ar: بمريض || tr: da ==>  0.0
# t(e|f)::  ar: بنتها || tr: da ==>  0.0
# t(e|f)::  ar: لصديقه || tr: da ==>  0.0
# t(e|f)::  ar: وكان || tr: da ==>  0.3333333333333333
# t(e|f)::  ar: " || tr: da ==>  0.0
# t(e|f)::  ar: أعتني || tr: da ==>  0.0
# t(e|f)::  ar: بالناس || tr: da ==>  0.0
# t(e|f)::  ar: تبدأ || tr: da ==>  0.0
# t(e|f)::  ar: محبطاً || tr: da ==>  0.0
# t(e|f)::  ar: الجنون || tr: da ==>  0.0
# t(e|f)::  ar: لذا، || tr: da ==>  0.0
# t(e|f)::  ar: الزوجين || tr: da ==>  0.0
# t(e|f)::  ar: كان || tr: da ==>  0.0
# t(e|f)::  ar: لهذين || tr: da ==>  0.0
# t(e|f)::  ar: وفي || tr: da ==>  0.0
# t(e|f)::  ar: بأمها || tr: da ==>  0.0
# t(e|f)::  ar: يجري || tr: da ==>  0.0
# t(e|f)::  ar: تأثير || tr: da ==>  0.0
# t(e|f)::  ar: ومعروفة || tr: da ==>  0.0
# t(e|f)::  ar: أقود || tr: da ==>  0.0
# t(e|f)::  ar: قبل || tr: da ==>  0.0
# t(e|f)::  ar: قد || tr: da ==>  0.0
# t(e|f)::  ar: مرهقة || tr: da ==>  0.0
# t(e|f)::  ar: "الحزن" || tr: da ==>  0.0
# t(e|f)::  ar: محدد || tr: da ==>  0.0
# t(e|f)::  ar: الموت || tr: da ==>  0.0
# t(e|f)::  ar: خلافاً || tr: da ==>  0.0
# t(e|f)::  ar: مختبري، || tr: da ==>  0.0
# t(e|f)::  ar: مرضهم || tr: da ==>  0.0
# t(e|f)::  ar: المثال، || tr: da ==>  0.0
# t(e|f)::  ar: الجانب || tr: da ==>  0.0
# t(e|f)::  ar: إتصل || tr: da ==>  0.0
# t(e|f)::  ar: ترجع || tr: da ==>  0.0
# t(e|f)::  ar: لما || tr: da ==>  0.0
# t(e|f)::  ar: أدرس || tr: da ==>  0.0
# t(e|f)::  ar: صديق || tr: da ==>  0.0
# t(e|f)::  ar: الجنوبي || tr: da ==>  0.0
# t(e|f)::  ar: لقبل || tr: da ==>  0.0
# t(e|f)::  ar: بها || tr: da ==>  0.0
# t(e|f)::  ar: إرهاق || tr: da ==>  0.0
# t(e|f)::  ar: الأرمل || tr: da ==>  0.0
# t(e|f)::  ar: جامعة || tr: da ==>  0.0
# t(e|f)::  ar: مكالمة || tr: da ==>  0.0
# t(e|f)::  ar: تعتني || tr: da ==>  0.0
# t(e|f)::  ar: عندما || tr: da ==>  0.0
# t(e|f)::  ar: من || tr: da ==>  0.0
# t(e|f)::  ar: بالنسبة || tr: da ==>  0.0
# t(e|f)::  ar: زوجتي || tr: da ==>  0.0
# t(e|f)::  ar: إمرأة || tr: da ==>  0.0
# t(e|f)::  ar: اللأخير || tr: da ==>  0.0
# t(e|f)::  ar: هذه || tr: da ==>  0.0
# t(e|f)::  ar: في || tr: da ==>  0.0
# t(e|f)::  ar: الأيام || tr: da ==>  0.0
# t(e|f)::  ar: مضت || tr: da ==>  0.0
# t(e|f)::  ar: بسبب || tr: da ==>  0.0
# t(e|f)::  ar: هو || tr: da ==>  0.0
# t(e|f)::  ar: ما || tr: da ==>  0.0
# t(e|f)::  ar: ب || tr: da ==>  0.0
# t(e|f)::  ar: السيارة || tr: da ==>  0.0
# t(e|f)::  ar: القصة || tr: da ==>  0.0
# t(e|f)::  ar: بي || tr: da ==>  0.0
# t(e|f)::  ar: الذين || tr: da ==>  0.0
# t(e|f)::  ar: فحينما || tr: da ==>  0.0
# t(e|f)::  ar: لشيكاغو || tr: da ==>  0.0
# t(e|f)::  ar: أراقب || tr: da ==>  0.0
# t(e|f)::  ar: وكانت || tr: da ==>  0.0
# t(e|f)::  ar: سبيل || tr: da ==>  0.0
# t(e|f)::  ar: زوج || tr: da ==>  0.3333333333333333
# t(e|f)::  ar: موت || tr: da ==>  0.0
# t(e|f)::  ar: مخاطر || tr: da ==>  0.0
# t(e|f)::  ar: إنكسار || tr: da ==>  0.0
# t(e|f)::  ar: حوالي || tr: da ==>  0.0
# t(e|f)::  ar: الأول || tr: da ==>  0.0
# t(e|f)::  ar: شيكاغو || tr: da ==>  0.0
# t(e|f)::  ar: الموت، || tr: da ==>  0.0
# t(e|f)::  ar: عاماً || tr: da ==>  0.0
# t(e|f)::  ar: وشك || tr: da ==>  0.0
# t(e|f)::  ar: قديمة || tr: da ==>  0.0
# t(e|f)::  ar: تتضاعف || tr: da ==>  0.0
# t(e|f)::  ar: لأنه || tr: da ==>  0.0
# t(e|f)::  ar: فكرة || tr: da ==>  0.0
# t(e|f)::  ar: الزوج || tr: da ==>  0.0
# t(e|f)::  ar: للناس || tr: da ==>  0.0
# t(e|f)::  ar: خلال || tr: da ==>  0.0
# t(e|f)::  ar: أموت، || tr: da ==>  0.0
# t(e|f)::  ar: العلوم || tr: da ==>  0.0
# t(e|f)::  ar: على || tr: da ==>  0.0
# t(e|f)::  ar: لي، || tr: da ==>  0.0
# t(e|f)::  ar: فترة || tr: da ==>  0.0
# t(e|f)::  ar: الحالة، || tr: da ==>  0.0
# t(e|f)::  ar: يحدث || tr: da ==>  0.0
# t(e|f)::  ar: جداً || tr: da ==>  0.0
# t(e|f)::  ar: وقد || tr: da ==>  0.0
# t(e|f)::  ar: كذلك || tr: da ==>  0.0
# t(e|f)::  ar: المنزل || tr: da ==>  0.0
# t(e|f)::  ar: شاركت || tr: da ==>  0.0
# t(e|f)::  ar: وكنت || tr: da ==>  0.0
# t(e|f)::  ar: العناية || tr: da ==>  0.0
# t(e|f)::  ar: تموت || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: طبيباً || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: 150 || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: إلى || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: وتلقيت || tr: arkadaşından ==>  0.2
# t(e|f)::  ar: أحد || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: الإجتماعية || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: وأسرهم || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: 15 || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: كنت || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: القلب." || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: العام || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: الذي || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: نزيلاً || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: الإبنة || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: تعب || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: زوجته || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: كانت || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: بمريض || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: بنتها || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: لصديقه || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: وكان || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: " || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: أعتني || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: بالناس || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: تبدأ || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: محبطاً || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: الجنون || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: لذا، || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: الزوجين || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: كان || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: لهذين || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: وفي || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: بأمها || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: يجري || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: تأثير || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: ومعروفة || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: أقود || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: قبل || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: قد || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: مرهقة || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: "الحزن" || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: محدد || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: الموت || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: خلافاً || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: مختبري، || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: مرضهم || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: المثال، || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: الجانب || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: إتصل || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: ترجع || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: لما || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: أدرس || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: صديق || tr: arkadaşından ==>  0.2
# t(e|f)::  ar: الجنوبي || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: لقبل || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: بها || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: إرهاق || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: الأرمل || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: جامعة || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: مكالمة || tr: arkadaşından ==>  0.2
# t(e|f)::  ar: تعتني || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: عندما || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: من || tr: arkadaşından ==>  0.2
# t(e|f)::  ar: بالنسبة || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: زوجتي || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: إمرأة || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: اللأخير || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: هذه || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: في || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: الأيام || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: مضت || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: بسبب || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: هو || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: ما || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: ب || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: السيارة || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: القصة || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: بي || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: الذين || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: فحينما || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: لشيكاغو || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: أراقب || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: وكانت || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: سبيل || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: زوج || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: موت || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: مخاطر || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: إنكسار || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: حوالي || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: الأول || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: شيكاغو || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: الموت، || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: عاماً || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: وشك || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: قديمة || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: تتضاعف || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: لأنه || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: فكرة || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: الزوج || tr: arkadaşından ==>  0.2
# t(e|f)::  ar: للناس || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: خلال || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: أموت، || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: العلوم || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: على || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: لي، || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: فترة || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: الحالة، || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: يحدث || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: جداً || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: وقد || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: كذلك || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: المنزل || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: شاركت || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: وكنت || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: العناية || tr: arkadaşından ==>  0.0
# t(e|f)::  ar: تموت || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: طبيباً || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: 150 || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: إلى || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: وتلقيت || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: أحد || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: الإجتماعية || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: وأسرهم || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: 15 || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: كنت || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: القلب." || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: العام || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: الذي || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: نزيلاً || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: الإبنة || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: تعب || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: زوجته || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: كانت || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: بمريض || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: بنتها || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: لصديقه || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: وكان || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: " || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: أعتني || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: بالناس || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: تبدأ || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: محبطاً || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: الجنون || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: لذا، || tr: öldüğümde, ==>  0.14285714285714288
# t(e|f)::  ar: الزوجين || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: كان || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: لهذين || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: وفي || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: بأمها || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: يجري || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: تأثير || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: ومعروفة || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: أقود || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: قبل || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: قد || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: مرهقة || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: "الحزن" || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: محدد || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: الموت || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: خلافاً || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: مختبري، || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: مرضهم || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: المثال، || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: الجانب || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: إتصل || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: ترجع || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: لما || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: أدرس || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: صديق || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: الجنوبي || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: لقبل || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: بها || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: إرهاق || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: الأرمل || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: جامعة || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: مكالمة || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: تعتني || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: عندما || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: من || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: بالنسبة || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: زوجتي || tr: öldüğümde, ==>  0.14285714285714288
# t(e|f)::  ar: إمرأة || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: اللأخير || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: هذه || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: في || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: الأيام || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: مضت || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: بسبب || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: هو || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: ما || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: ب || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: السيارة || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: القصة || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: بي || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: الذين || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: فحينما || tr: öldüğümde, ==>  0.14285714285714288
# t(e|f)::  ar: لشيكاغو || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: أراقب || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: وكانت || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: سبيل || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: زوج || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: موت || tr: öldüğümde, ==>  0.14285714285714288
# t(e|f)::  ar: مخاطر || tr: öldüğümde, ==>  0.14285714285714288
# t(e|f)::  ar: إنكسار || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: حوالي || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: الأول || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: شيكاغو || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: الموت، || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: عاماً || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: وشك || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: قديمة || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: تتضاعف || tr: öldüğümde, ==>  0.14285714285714288
# t(e|f)::  ar: لأنه || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: فكرة || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: الزوج || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: للناس || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: خلال || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: أموت، || tr: öldüğümde, ==>  0.14285714285714288
# t(e|f)::  ar: العلوم || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: على || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: لي، || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: فترة || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: الحالة، || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: يحدث || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: جداً || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: وقد || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: كذلك || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: المنزل || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: شاركت || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: وكنت || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: العناية || tr: öldüğümde, ==>  0.0
# t(e|f)::  ar: تموت || tr: hikaye ==>  0.0
# t(e|f)::  ar: طبيباً || tr: hikaye ==>  0.0
# t(e|f)::  ar: 150 || tr: hikaye ==>  0.0
# t(e|f)::  ar: إلى || tr: hikaye ==>  0.0
# t(e|f)::  ar: وتلقيت || tr: hikaye ==>  0.0
# t(e|f)::  ar: أحد || tr: hikaye ==>  0.0
# t(e|f)::  ar: الإجتماعية || tr: hikaye ==>  0.0
# t(e|f)::  ar: وأسرهم || tr: hikaye ==>  0.0
# t(e|f)::  ar: 15 || tr: hikaye ==>  0.1
# t(e|f)::  ar: كنت || tr: hikaye ==>  0.0
# t(e|f)::  ar: القلب." || tr: hikaye ==>  0.0
# t(e|f)::  ar: العام || tr: hikaye ==>  0.0
# t(e|f)::  ar: الذي || tr: hikaye ==>  0.0
# t(e|f)::  ar: نزيلاً || tr: hikaye ==>  0.0
# t(e|f)::  ar: الإبنة || tr: hikaye ==>  0.0
# t(e|f)::  ar: تعب || tr: hikaye ==>  0.0
# t(e|f)::  ar: زوجته || tr: hikaye ==>  0.0
# t(e|f)::  ar: كانت || tr: hikaye ==>  0.0
# t(e|f)::  ar: بمريض || tr: hikaye ==>  0.0
# t(e|f)::  ar: بنتها || tr: hikaye ==>  0.0
# t(e|f)::  ar: لصديقه || tr: hikaye ==>  0.0
# t(e|f)::  ar: وكان || tr: hikaye ==>  0.0
# t(e|f)::  ar: " || tr: hikaye ==>  0.0
# t(e|f)::  ar: أعتني || tr: hikaye ==>  0.0
# t(e|f)::  ar: بالناس || tr: hikaye ==>  0.0
# t(e|f)::  ar: تبدأ || tr: hikaye ==>  0.1
# t(e|f)::  ar: محبطاً || tr: hikaye ==>  0.0
# t(e|f)::  ar: الجنون || tr: hikaye ==>  0.0
# t(e|f)::  ar: لذا، || tr: hikaye ==>  0.0
# t(e|f)::  ar: الزوجين || tr: hikaye ==>  0.0
# t(e|f)::  ar: كان || tr: hikaye ==>  0.0
# t(e|f)::  ar: لهذين || tr: hikaye ==>  0.0
# t(e|f)::  ar: وفي || tr: hikaye ==>  0.0
# t(e|f)::  ar: بأمها || tr: hikaye ==>  0.0
# t(e|f)::  ar: يجري || tr: hikaye ==>  0.0
# t(e|f)::  ar: تأثير || tr: hikaye ==>  0.0
# t(e|f)::  ar: ومعروفة || tr: hikaye ==>  0.0
# t(e|f)::  ar: أقود || tr: hikaye ==>  0.0
# t(e|f)::  ar: قبل || tr: hikaye ==>  0.1
# t(e|f)::  ar: قد || tr: hikaye ==>  0.0
# t(e|f)::  ar: مرهقة || tr: hikaye ==>  0.0
# t(e|f)::  ar: "الحزن" || tr: hikaye ==>  0.0
# t(e|f)::  ar: محدد || tr: hikaye ==>  0.0
# t(e|f)::  ar: الموت || tr: hikaye ==>  0.0
# t(e|f)::  ar: خلافاً || tr: hikaye ==>  0.0
# t(e|f)::  ar: مختبري، || tr: hikaye ==>  0.0
# t(e|f)::  ar: مرضهم || tr: hikaye ==>  0.0
# t(e|f)::  ar: المثال، || tr: hikaye ==>  0.0
# t(e|f)::  ar: الجانب || tr: hikaye ==>  0.0
# t(e|f)::  ar: إتصل || tr: hikaye ==>  0.0
# t(e|f)::  ar: ترجع || tr: hikaye ==>  0.0
# t(e|f)::  ar: لما || tr: hikaye ==>  0.0
# t(e|f)::  ar: أدرس || tr: hikaye ==>  0.0
# t(e|f)::  ar: صديق || tr: hikaye ==>  0.0
# t(e|f)::  ar: الجنوبي || tr: hikaye ==>  0.0
# t(e|f)::  ar: لقبل || tr: hikaye ==>  0.0
# t(e|f)::  ar: بها || tr: hikaye ==>  0.0
# t(e|f)::  ar: إرهاق || tr: hikaye ==>  0.0
# t(e|f)::  ar: الأرمل || tr: hikaye ==>  0.0
# t(e|f)::  ar: جامعة || tr: hikaye ==>  0.0
# t(e|f)::  ar: مكالمة || tr: hikaye ==>  0.0
# t(e|f)::  ar: تعتني || tr: hikaye ==>  0.0
# t(e|f)::  ar: عندما || tr: hikaye ==>  0.0
# t(e|f)::  ar: من || tr: hikaye ==>  0.0
# t(e|f)::  ar: بالنسبة || tr: hikaye ==>  0.1
# t(e|f)::  ar: زوجتي || tr: hikaye ==>  0.0
# t(e|f)::  ar: إمرأة || tr: hikaye ==>  0.0
# t(e|f)::  ar: اللأخير || tr: hikaye ==>  0.0
# t(e|f)::  ar: هذه || tr: hikaye ==>  0.1
# t(e|f)::  ar: في || tr: hikaye ==>  0.0
# t(e|f)::  ar: الأيام || tr: hikaye ==>  0.0
# t(e|f)::  ar: مضت || tr: hikaye ==>  0.1
# t(e|f)::  ar: بسبب || tr: hikaye ==>  0.0
# t(e|f)::  ar: هو || tr: hikaye ==>  0.0
# t(e|f)::  ar: ما || tr: hikaye ==>  0.0
# t(e|f)::  ar: ب || tr: hikaye ==>  0.0
# t(e|f)::  ar: السيارة || tr: hikaye ==>  0.0
# t(e|f)::  ar: القصة || tr: hikaye ==>  0.1
# t(e|f)::  ar: بي || tr: hikaye ==>  0.0
# t(e|f)::  ar: الذين || tr: hikaye ==>  0.0
# t(e|f)::  ar: فحينما || tr: hikaye ==>  0.0
# t(e|f)::  ar: لشيكاغو || tr: hikaye ==>  0.0
# t(e|f)::  ar: أراقب || tr: hikaye ==>  0.0
# t(e|f)::  ar: وكانت || tr: hikaye ==>  0.0
# t(e|f)::  ar: سبيل || tr: hikaye ==>  0.0
# t(e|f)::  ar: زوج || tr: hikaye ==>  0.0
# t(e|f)::  ar: موت || tr: hikaye ==>  0.0
# t(e|f)::  ar: مخاطر || tr: hikaye ==>  0.0
# t(e|f)::  ar: إنكسار || tr: hikaye ==>  0.0
# t(e|f)::  ar: حوالي || tr: hikaye ==>  0.1
# t(e|f)::  ar: الأول || tr: hikaye ==>  0.0
# t(e|f)::  ar: شيكاغو || tr: hikaye ==>  0.0
# t(e|f)::  ar: الموت، || tr: hikaye ==>  0.0
# t(e|f)::  ar: عاماً || tr: hikaye ==>  0.1
# t(e|f)::  ar: وشك || tr: hikaye ==>  0.0
# t(e|f)::  ar: قديمة || tr: hikaye ==>  0.0
# t(e|f)::  ar: تتضاعف || tr: hikaye ==>  0.0
# t(e|f)::  ar: لأنه || tr: hikaye ==>  0.0
# t(e|f)::  ar: فكرة || tr: hikaye ==>  0.0
# t(e|f)::  ar: الزوج || tr: hikaye ==>  0.0
# t(e|f)::  ar: للناس || tr: hikaye ==>  0.0
# t(e|f)::  ar: خلال || tr: hikaye ==>  0.0
# t(e|f)::  ar: أموت، || tr: hikaye ==>  0.0
# t(e|f)::  ar: العلوم || tr: hikaye ==>  0.0
# t(e|f)::  ar: على || tr: hikaye ==>  0.0
# t(e|f)::  ar: لي، || tr: hikaye ==>  0.1
# t(e|f)::  ar: فترة || tr: hikaye ==>  0.0
# t(e|f)::  ar: الحالة، || tr: hikaye ==>  0.0
# t(e|f)::  ar: يحدث || tr: hikaye ==>  0.0
# t(e|f)::  ar: جداً || tr: hikaye ==>  0.0
# t(e|f)::  ar: وقد || tr: hikaye ==>  0.0
# t(e|f)::  ar: كذلك || tr: hikaye ==>  0.0
# t(e|f)::  ar: المنزل || tr: hikaye ==>  0.0
# t(e|f)::  ar: شاركت || tr: hikaye ==>  0.0
# t(e|f)::  ar: وكنت || tr: hikaye ==>  0.0
# t(e|f)::  ar: العناية || tr: hikaye ==>  0.0
# t(e|f)::  ar: تموت || tr: 150 ==>  0.0
# t(e|f)::  ar: طبيباً || tr: 150 ==>  0.0
# t(e|f)::  ar: 150 || tr: 150 ==>  0.0
# t(e|f)::  ar: إلى || tr: 150 ==>  0.0
# t(e|f)::  ar: وتلقيت || tr: 150 ==>  0.0
# t(e|f)::  ar: أحد || tr: 150 ==>  0.0
# t(e|f)::  ar: الإجتماعية || tr: 150 ==>  0.125
# t(e|f)::  ar: وأسرهم || tr: 150 ==>  0.0
# t(e|f)::  ar: 15 || tr: 150 ==>  0.0
# t(e|f)::  ar: كنت || tr: 150 ==>  0.0
# t(e|f)::  ar: القلب." || tr: 150 ==>  0.0
# t(e|f)::  ar: العام || tr: 150 ==>  0.0
# t(e|f)::  ar: الذي || tr: 150 ==>  0.125
# t(e|f)::  ar: نزيلاً || tr: 150 ==>  0.0
# t(e|f)::  ar: الإبنة || tr: 150 ==>  0.0
# t(e|f)::  ar: تعب || tr: 150 ==>  0.0
# t(e|f)::  ar: زوجته || tr: 150 ==>  0.0
# t(e|f)::  ar: كانت || tr: 150 ==>  0.0
# t(e|f)::  ar: بمريض || tr: 150 ==>  0.0
# t(e|f)::  ar: بنتها || tr: 150 ==>  0.0
# t(e|f)::  ar: لصديقه || tr: 150 ==>  0.0
# t(e|f)::  ar: وكان || tr: 150 ==>  0.0
# t(e|f)::  ar: " || tr: 150 ==>  0.0
# t(e|f)::  ar: أعتني || tr: 150 ==>  0.0
# t(e|f)::  ar: بالناس || tr: 150 ==>  0.0
# t(e|f)::  ar: تبدأ || tr: 150 ==>  0.0
# t(e|f)::  ar: محبطاً || tr: 150 ==>  0.0
# t(e|f)::  ar: الجنون || tr: 150 ==>  0.0
# t(e|f)::  ar: لذا، || tr: 150 ==>  0.0
# t(e|f)::  ar: الزوجين || tr: 150 ==>  0.0
# t(e|f)::  ar: كان || tr: 150 ==>  0.0
# t(e|f)::  ar: لهذين || tr: 150 ==>  0.0
# t(e|f)::  ar: وفي || tr: 150 ==>  0.0
# t(e|f)::  ar: بأمها || tr: 150 ==>  0.0
# t(e|f)::  ar: يجري || tr: 150 ==>  0.0
# t(e|f)::  ar: تأثير || tr: 150 ==>  0.0
# t(e|f)::  ar: ومعروفة || tr: 150 ==>  0.0
# t(e|f)::  ar: أقود || tr: 150 ==>  0.0
# t(e|f)::  ar: قبل || tr: 150 ==>  0.0
# t(e|f)::  ar: قد || tr: 150 ==>  0.0
# t(e|f)::  ar: مرهقة || tr: 150 ==>  0.0
# t(e|f)::  ar: "الحزن" || tr: 150 ==>  0.0
# t(e|f)::  ar: محدد || tr: 150 ==>  0.0
# t(e|f)::  ar: الموت || tr: 150 ==>  0.0
# t(e|f)::  ar: خلافاً || tr: 150 ==>  0.0
# t(e|f)::  ar: مختبري، || tr: 150 ==>  0.0
# t(e|f)::  ar: مرضهم || tr: 150 ==>  0.0
# t(e|f)::  ar: المثال، || tr: 150 ==>  0.0
# t(e|f)::  ar: الجانب || tr: 150 ==>  0.0
# t(e|f)::  ar: إتصل || tr: 150 ==>  0.0
# t(e|f)::  ar: ترجع || tr: 150 ==>  0.0
# t(e|f)::  ar: لما || tr: 150 ==>  0.0
# t(e|f)::  ar: أدرس || tr: 150 ==>  0.0
# t(e|f)::  ar: صديق || tr: 150 ==>  0.0
# t(e|f)::  ar: الجنوبي || tr: 150 ==>  0.0
# t(e|f)::  ar: لقبل || tr: 150 ==>  0.0
# t(e|f)::  ar: بها || tr: 150 ==>  0.0
# t(e|f)::  ar: إرهاق || tr: 150 ==>  0.0
# t(e|f)::  ar: الأرمل || tr: 150 ==>  0.0
# t(e|f)::  ar: جامعة || tr: 150 ==>  0.0
# t(e|f)::  ar: مكالمة || tr: 150 ==>  0.0
# t(e|f)::  ar: تعتني || tr: 150 ==>  0.0
# t(e|f)::  ar: عندما || tr: 150 ==>  0.0
# t(e|f)::  ar: من || tr: 150 ==>  0.0
# t(e|f)::  ar: بالنسبة || tr: 150 ==>  0.0
# t(e|f)::  ar: زوجتي || tr: 150 ==>  0.0
# t(e|f)::  ar: إمرأة || tr: 150 ==>  0.0
# t(e|f)::  ar: اللأخير || tr: 150 ==>  0.0
# t(e|f)::  ar: هذه || tr: 150 ==>  0.0
# t(e|f)::  ar: في || tr: 150 ==>  0.125
# t(e|f)::  ar: الأيام || tr: 150 ==>  0.0
# t(e|f)::  ar: مضت || tr: 150 ==>  0.0
# t(e|f)::  ar: بسبب || tr: 150 ==>  0.0
# t(e|f)::  ar: هو || tr: 150 ==>  0.125
# t(e|f)::  ar: ما || tr: 150 ==>  0.0
# t(e|f)::  ar: ب || tr: 150 ==>  0.0
# t(e|f)::  ar: السيارة || tr: 150 ==>  0.0
# t(e|f)::  ar: القصة || tr: 150 ==>  0.0
# t(e|f)::  ar: بي || tr: 150 ==>  0.0
# t(e|f)::  ar: الذين || tr: 150 ==>  0.0
# t(e|f)::  ar: فحينما || tr: 150 ==>  0.0
# t(e|f)::  ar: لشيكاغو || tr: 150 ==>  0.0
# t(e|f)::  ar: أراقب || tr: 150 ==>  0.0
# t(e|f)::  ar: وكانت || tr: 150 ==>  0.0
# t(e|f)::  ar: سبيل || tr: 150 ==>  0.0
# t(e|f)::  ar: زوج || tr: 150 ==>  0.0
# t(e|f)::  ar: موت || tr: 150 ==>  0.0
# t(e|f)::  ar: مخاطر || tr: 150 ==>  0.0
# t(e|f)::  ar: إنكسار || tr: 150 ==>  0.0
# t(e|f)::  ar: حوالي || tr: 150 ==>  0.0
# t(e|f)::  ar: الأول || tr: 150 ==>  0.0
# t(e|f)::  ar: شيكاغو || tr: 150 ==>  0.0
# t(e|f)::  ar: الموت، || tr: 150 ==>  0.0
# t(e|f)::  ar: عاماً || tr: 150 ==>  0.0
# t(e|f)::  ar: وشك || tr: 150 ==>  0.0
# t(e|f)::  ar: قديمة || tr: 150 ==>  0.125
# t(e|f)::  ar: تتضاعف || tr: 150 ==>  0.0
# t(e|f)::  ar: لأنه || tr: 150 ==>  0.0
# t(e|f)::  ar: فكرة || tr: 150 ==>  0.125
# t(e|f)::  ar: الزوج || tr: 150 ==>  0.0
# t(e|f)::  ar: للناس || tr: 150 ==>  0.0
# t(e|f)::  ar: خلال || tr: 150 ==>  0.0
# t(e|f)::  ar: أموت، || tr: 150 ==>  0.0
# t(e|f)::  ar: العلوم || tr: 150 ==>  0.125
# t(e|f)::  ar: على || tr: 150 ==>  0.0
# t(e|f)::  ar: لي، || tr: 150 ==>  0.0
# t(e|f)::  ar: فترة || tr: 150 ==>  0.0
# t(e|f)::  ar: الحالة، || tr: 150 ==>  0.0
# t(e|f)::  ar: يحدث || tr: 150 ==>  0.0
# t(e|f)::  ar: جداً || tr: 150 ==>  0.125
# t(e|f)::  ar: وقد || tr: 150 ==>  0.0
# t(e|f)::  ar: كذلك || tr: 150 ==>  0.0
# t(e|f)::  ar: المنزل || tr: 150 ==>  0.0
# t(e|f)::  ar: شاركت || tr: 150 ==>  0.0
# t(e|f)::  ar: وكنت || tr: 150 ==>  0.0
# t(e|f)::  ar: العناية || tr: 150 ==>  0.0
# t(e|f)::  ar: تموت || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: طبيباً || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: 150 || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: إلى || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: وتلقيت || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: أحد || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: الإجتماعية || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: وأسرهم || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: 15 || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: كنت || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: القلب." || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: العام || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: الذي || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: نزيلاً || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: الإبنة || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: تعب || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: زوجته || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: كانت || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: بمريض || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: بنتها || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: لصديقه || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: وكان || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: " || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: أعتني || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: بالناس || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: تبدأ || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: محبطاً || tr: arkadaşına ==>  0.2
# t(e|f)::  ar: الجنون || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: لذا، || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: الزوجين || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: كان || tr: arkadaşına ==>  0.2
# t(e|f)::  ar: لهذين || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: وفي || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: بأمها || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: يجري || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: تأثير || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: ومعروفة || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: أقود || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: قبل || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: قد || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: مرهقة || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: "الحزن" || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: محدد || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: الموت || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: خلافاً || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: مختبري، || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: مرضهم || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: المثال، || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: الجانب || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: إتصل || tr: arkadaşına ==>  0.2
# t(e|f)::  ar: ترجع || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: لما || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: أدرس || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: صديق || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: الجنوبي || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: لقبل || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: بها || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: إرهاق || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: الأرمل || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: جامعة || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: مكالمة || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: تعتني || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: عندما || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: من || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: بالنسبة || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: زوجتي || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: إمرأة || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: اللأخير || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: هذه || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: في || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: الأيام || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: مضت || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: بسبب || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: هو || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: ما || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: ب || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: السيارة || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: القصة || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: بي || tr: arkadaşına ==>  0.2
# t(e|f)::  ar: الذين || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: فحينما || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: لشيكاغو || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: أراقب || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: وكانت || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: سبيل || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: زوج || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: موت || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: مخاطر || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: إنكسار || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: حوالي || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: الأول || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: شيكاغو || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: الموت، || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: عاماً || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: وشك || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: قديمة || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: تتضاعف || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: لأنه || tr: arkadaşına ==>  0.2
# t(e|f)::  ar: فكرة || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: الزوج || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: للناس || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: خلال || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: أموت، || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: العلوم || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: على || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: لي، || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: فترة || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: الحالة، || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: يحدث || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: جداً || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: وقد || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: كذلك || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: المنزل || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: شاركت || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: وكنت || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: العناية || tr: arkadaşına ==>  0.0
# t(e|f)::  ar: تموت || tr: yıl ==>  0.0
# t(e|f)::  ar: طبيباً || tr: yıl ==>  0.0
# t(e|f)::  ar: 150 || tr: yıl ==>  0.0
# t(e|f)::  ar: إلى || tr: yıl ==>  0.0
# t(e|f)::  ar: وتلقيت || tr: yıl ==>  0.0
# t(e|f)::  ar: أحد || tr: yıl ==>  0.0
# t(e|f)::  ar: الإجتماعية || tr: yıl ==>  0.125
# t(e|f)::  ar: وأسرهم || tr: yıl ==>  0.0
# t(e|f)::  ar: 15 || tr: yıl ==>  0.0
# t(e|f)::  ar: كنت || tr: yıl ==>  0.0
# t(e|f)::  ar: القلب." || tr: yıl ==>  0.0
# t(e|f)::  ar: العام || tr: yıl ==>  0.0
# t(e|f)::  ar: الذي || tr: yıl ==>  0.125
# t(e|f)::  ar: نزيلاً || tr: yıl ==>  0.0
# t(e|f)::  ar: الإبنة || tr: yıl ==>  0.0
# t(e|f)::  ar: تعب || tr: yıl ==>  0.0
# t(e|f)::  ar: زوجته || tr: yıl ==>  0.0
# t(e|f)::  ar: كانت || tr: yıl ==>  0.0
# t(e|f)::  ar: بمريض || tr: yıl ==>  0.0
# t(e|f)::  ar: بنتها || tr: yıl ==>  0.0
# t(e|f)::  ar: لصديقه || tr: yıl ==>  0.0
# t(e|f)::  ar: وكان || tr: yıl ==>  0.0
# t(e|f)::  ar: " || tr: yıl ==>  0.0
# t(e|f)::  ar: أعتني || tr: yıl ==>  0.0
# t(e|f)::  ar: بالناس || tr: yıl ==>  0.0
# t(e|f)::  ar: تبدأ || tr: yıl ==>  0.0
# t(e|f)::  ar: محبطاً || tr: yıl ==>  0.0
# t(e|f)::  ar: الجنون || tr: yıl ==>  0.0
# t(e|f)::  ar: لذا، || tr: yıl ==>  0.0
# t(e|f)::  ar: الزوجين || tr: yıl ==>  0.0
# t(e|f)::  ar: كان || tr: yıl ==>  0.0
# t(e|f)::  ar: لهذين || tr: yıl ==>  0.0
# t(e|f)::  ar: وفي || tr: yıl ==>  0.0
# t(e|f)::  ar: بأمها || tr: yıl ==>  0.0
# t(e|f)::  ar: يجري || tr: yıl ==>  0.0
# t(e|f)::  ar: تأثير || tr: yıl ==>  0.0
# t(e|f)::  ar: ومعروفة || tr: yıl ==>  0.0
# t(e|f)::  ar: أقود || tr: yıl ==>  0.0
# t(e|f)::  ar: قبل || tr: yıl ==>  0.0
# t(e|f)::  ar: قد || tr: yıl ==>  0.0
# t(e|f)::  ar: مرهقة || tr: yıl ==>  0.0
# t(e|f)::  ar: "الحزن" || tr: yıl ==>  0.0
# t(e|f)::  ar: محدد || tr: yıl ==>  0.0
# t(e|f)::  ar: الموت || tr: yıl ==>  0.0
# t(e|f)::  ar: خلافاً || tr: yıl ==>  0.0
# t(e|f)::  ar: مختبري، || tr: yıl ==>  0.0
# t(e|f)::  ar: مرضهم || tr: yıl ==>  0.0
# t(e|f)::  ar: المثال، || tr: yıl ==>  0.0
# t(e|f)::  ar: الجانب || tr: yıl ==>  0.0
# t(e|f)::  ar: إتصل || tr: yıl ==>  0.0
# t(e|f)::  ar: ترجع || tr: yıl ==>  0.0
# t(e|f)::  ar: لما || tr: yıl ==>  0.0
# t(e|f)::  ar: أدرس || tr: yıl ==>  0.0
# t(e|f)::  ar: صديق || tr: yıl ==>  0.0
# t(e|f)::  ar: الجنوبي || tr: yıl ==>  0.0
# t(e|f)::  ar: لقبل || tr: yıl ==>  0.0
# t(e|f)::  ar: بها || tr: yıl ==>  0.0
# t(e|f)::  ar: إرهاق || tr: yıl ==>  0.0
# t(e|f)::  ar: الأرمل || tr: yıl ==>  0.0
# t(e|f)::  ar: جامعة || tr: yıl ==>  0.0
# t(e|f)::  ar: مكالمة || tr: yıl ==>  0.0
# t(e|f)::  ar: تعتني || tr: yıl ==>  0.0
# t(e|f)::  ar: عندما || tr: yıl ==>  0.0
# t(e|f)::  ar: من || tr: yıl ==>  0.0
# t(e|f)::  ar: بالنسبة || tr: yıl ==>  0.0
# t(e|f)::  ar: زوجتي || tr: yıl ==>  0.0
# t(e|f)::  ar: إمرأة || tr: yıl ==>  0.0
# t(e|f)::  ar: اللأخير || tr: yıl ==>  0.0
# t(e|f)::  ar: هذه || tr: yıl ==>  0.0
# t(e|f)::  ar: في || tr: yıl ==>  0.125
# t(e|f)::  ar: الأيام || tr: yıl ==>  0.0
# t(e|f)::  ar: مضت || tr: yıl ==>  0.0
# t(e|f)::  ar: بسبب || tr: yıl ==>  0.0
# t(e|f)::  ar: هو || tr: yıl ==>  0.125
# t(e|f)::  ar: ما || tr: yıl ==>  0.0
# t(e|f)::  ar: ب || tr: yıl ==>  0.0
# t(e|f)::  ar: السيارة || tr: yıl ==>  0.0
# t(e|f)::  ar: القصة || tr: yıl ==>  0.0
# t(e|f)::  ar: بي || tr: yıl ==>  0.0
# t(e|f)::  ar: الذين || tr: yıl ==>  0.0
# t(e|f)::  ar: فحينما || tr: yıl ==>  0.0
# t(e|f)::  ar: لشيكاغو || tr: yıl ==>  0.0
# t(e|f)::  ar: أراقب || tr: yıl ==>  0.0
# t(e|f)::  ar: وكانت || tr: yıl ==>  0.0
# t(e|f)::  ar: سبيل || tr: yıl ==>  0.0
# t(e|f)::  ar: زوج || tr: yıl ==>  0.0
# t(e|f)::  ar: موت || tr: yıl ==>  0.0
# t(e|f)::  ar: مخاطر || tr: yıl ==>  0.0
# t(e|f)::  ar: إنكسار || tr: yıl ==>  0.0
# t(e|f)::  ar: حوالي || tr: yıl ==>  0.0
# t(e|f)::  ar: الأول || tr: yıl ==>  0.0
# t(e|f)::  ar: شيكاغو || tr: yıl ==>  0.0
# t(e|f)::  ar: الموت، || tr: yıl ==>  0.0
# t(e|f)::  ar: عاماً || tr: yıl ==>  0.0
# t(e|f)::  ar: وشك || tr: yıl ==>  0.0
# t(e|f)::  ar: قديمة || tr: yıl ==>  0.125
# t(e|f)::  ar: تتضاعف || tr: yıl ==>  0.0
# t(e|f)::  ar: لأنه || tr: yıl ==>  0.0
# t(e|f)::  ar: فكرة || tr: yıl ==>  0.125
# t(e|f)::  ar: الزوج || tr: yıl ==>  0.0
# t(e|f)::  ar: للناس || tr: yıl ==>  0.0
# t(e|f)::  ar: خلال || tr: yıl ==>  0.0
# t(e|f)::  ar: أموت، || tr: yıl ==>  0.0
# t(e|f)::  ar: العلوم || tr: yıl ==>  0.125
# t(e|f)::  ar: على || tr: yıl ==>  0.0
# t(e|f)::  ar: لي، || tr: yıl ==>  0.0
# t(e|f)::  ar: فترة || tr: yıl ==>  0.0
# t(e|f)::  ar: الحالة، || tr: yıl ==>  0.0
# t(e|f)::  ar: يحدث || tr: yıl ==>  0.0
# t(e|f)::  ar: جداً || tr: yıl ==>  0.125
# t(e|f)::  ar: وقد || tr: yıl ==>  0.0
# t(e|f)::  ar: كذلك || tr: yıl ==>  0.0
# t(e|f)::  ar: المنزل || tr: yıl ==>  0.0
# t(e|f)::  ar: شاركت || tr: yıl ==>  0.0
# t(e|f)::  ar: وكنت || tr: yıl ==>  0.0
# t(e|f)::  ar: العناية || tr: yıl ==>  0.0
# t(e|f)::  ar: تموت || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: طبيباً || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: 150 || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: إلى || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: وتلقيت || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: أحد || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: الإجتماعية || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: وأسرهم || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: 15 || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: كنت || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: القلب." || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: العام || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: الذي || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: نزيلاً || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: الإبنة || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: تعب || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: زوجته || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: كانت || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: بمريض || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: بنتها || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: لصديقه || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: وكان || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: " || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: أعتني || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: بالناس || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: تبدأ || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: محبطاً || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: الجنون || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: لذا، || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: الزوجين || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: كان || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: لهذين || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: وفي || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: بأمها || tr: bakıyordum ==>  0.0
# t(e|f)::  ar: يجري || tr: bakıyordum ==>  0.0
# ...
# t(e|f)::  ar: وكانت || tr: ilk ==>  0.0
# t(e|f)::  ar: سبيل || tr: ilk ==>  0.0
# t(e|f)::  ar: زوج || tr: ilk ==>  0.0
# t(e|f)::  ar: موت || tr: ilk ==>  0.14285714285714285
# t(e|f)::  ar: مخاطر || tr: ilk ==>  0.14285714285714285
# t(e|f)::  ar: إنكسار || tr: ilk ==>  0.0
# t(e|f)::  ar: حوالي || tr: ilk ==>  0.0
# t(e|f)::  ar: الأول || tr: ilk ==>  0.0
# t(e|f)::  ar: شيكاغو || tr: ilk ==>  0.0
# t(e|f)::  ar: الموت، || tr: ilk ==>  0.0
# t(e|f)::  ar: عاماً || tr: ilk ==>  0.0
# t(e|f)::  ar: وشك || tr: ilk ==>  0.0
# t(e|f)::  ar: قديمة || tr: ilk ==>  0.0
# t(e|f)::  ar: تتضاعف || tr: ilk ==>  0.14285714285714285
# t(e|f)::  ar: لأنه || tr: ilk ==>  0.0
# t(e|f)::  ar: فكرة || tr: ilk ==>  0.0
# t(e|f)::  ar: الزوج || tr: ilk ==>  0.0
# t(e|f)::  ar: للناس || tr: ilk ==>  0.0
# t(e|f)::  ar: خلال || tr: ilk ==>  0.0
# t(e|f)::  ar: أموت، || tr: ilk ==>  0.14285714285714285
# t(e|f)::  ar: العلوم || tr: ilk ==>  0.0
# t(e|f)::  ar: على || tr: ilk ==>  0.0
# t(e|f)::  ar: لي، || tr: ilk ==>  0.0
# t(e|f)::  ar: فترة || tr: ilk ==>  0.0
# t(e|f)::  ar: الحالة، || tr: ilk ==>  0.0
# t(e|f)::  ar: يحدث || tr: ilk ==>  0.0
# t(e|f)::  ar: جداً || tr: ilk ==>  0.0
# t(e|f)::  ar: وقد || tr: ilk ==>  0.0
# t(e|f)::  ar: كذلك || tr: ilk ==>  0.0
# t(e|f)::  ar: المنزل || tr: ilk ==>  0.0
# t(e|f)::  ar: شاركت || tr: ilk ==>  0.0
# t(e|f)::  ar: وكنت || tr: ilk ==>  0.0
# t(e|f)::  ar: العناية || tr: ilk ==>  0.0
# t(e|f)::  ar: تموت || tr: Ve ==>  0.0
# t(e|f)::  ar: طبيباً || tr: Ve ==>  0.0
# t(e|f)::  ar: 150 || tr: Ve ==>  0.0
# t(e|f)::  ar: إلى || tr: Ve ==>  0.035808014480616185
# t(e|f)::  ar: وتلقيت || tr: Ve ==>  0.0
# t(e|f)::  ar: أحد || tr: Ve ==>  0.035808014480616185
# t(e|f)::  ar: الإجتماعية || tr: Ve ==>  0.0
# t(e|f)::  ar: وأسرهم || tr: Ve ==>  0.05527524021828934
# t(e|f)::  ar: 15 || tr: Ve ==>  0.0
# t(e|f)::  ar: كنت || tr: Ve ==>  0.0
# t(e|f)::  ar: القلب." || tr: Ve ==>  0.0
# t(e|f)::  ar: العام || tr: Ve ==>  0.0
# t(e|f)::  ar: الذي || tr: Ve ==>  0.0
# t(e|f)::  ar: نزيلاً || tr: Ve ==>  0.0
# t(e|f)::  ar: الإبنة || tr: Ve ==>  0.08664750396158066
# t(e|f)::  ar: تعب || tr: Ve ==>  0.0
# t(e|f)::  ar: زوجته || tr: Ve ==>  0.0
# t(e|f)::  ar: كانت || tr: Ve ==>  0.0
# t(e|f)::  ar: بمريض || tr: Ve ==>  0.012997997391080273
# t(e|f)::  ar: بنتها || tr: Ve ==>  0.0
# t(e|f)::  ar: لصديقه || tr: Ve ==>  0.0
# t(e|f)::  ar: وكان || tr: Ve ==>  0.024532145784054545
# t(e|f)::  ar: " || tr: Ve ==>  0.0
# t(e|f)::  ar: أعتني || tr: Ve ==>  0.01676730414895306
# t(e|f)::  ar: بالناس || tr: Ve ==>  0.01676730414895306
# t(e|f)::  ar: تبدأ || tr: Ve ==>  0.0
# t(e|f)::  ar: محبطاً || tr: Ve ==>  0.0
# t(e|f)::  ar: الجنون || tr: Ve ==>  0.0
# t(e|f)::  ar: لذا، || tr: Ve ==>  0.0
# t(e|f)::  ar: الزوجين || tr: Ve ==>  0.0
# t(e|f)::  ar: كان || tr: Ve ==>  0.0
# t(e|f)::  ar: لهذين || tr: Ve ==>  0.0
# t(e|f)::  ar: وفي || tr: Ve ==>  0.0
# t(e|f)::  ar: بأمها || tr: Ve ==>  0.019803952197016784
# t(e|f)::  ar: يجري || tr: Ve ==>  0.0
# t(e|f)::  ar: تأثير || tr: Ve ==>  0.0
# t(e|f)::  ar: ومعروفة || tr: Ve ==>  0.0
# t(e|f)::  ar: أقود || tr: Ve ==>  0.035808014480616185
# t(e|f)::  ar: قبل || tr: Ve ==>  0.0
# t(e|f)::  ar: قد || tr: Ve ==>  0.0
# t(e|f)::  ar: مرهقة || tr: Ve ==>  0.019803952197016784
# t(e|f)::  ar: "الحزن" || tr: Ve ==>  0.0
# t(e|f)::  ar: محدد || tr: Ve ==>  0.012997997391080273
# t(e|f)::  ar: الموت || tr: Ve ==>  0.0
# t(e|f)::  ar: خلافاً || tr: Ve ==>  0.0
# t(e|f)::  ar: مختبري، || tr: Ve ==>  0.0
# t(e|f)::  ar: مرضهم || tr: Ve ==>  0.0
# t(e|f)::  ar: المثال، || tr: Ve ==>  0.0
# t(e|f)::  ar: الجانب || tr: Ve ==>  0.0
# t(e|f)::  ar: إتصل || tr: Ve ==>  0.0
# t(e|f)::  ar: ترجع || tr: Ve ==>  0.0
# t(e|f)::  ar: لما || tr: Ve ==>  0.0
# t(e|f)::  ar: أدرس || tr: Ve ==>  0.0
# t(e|f)::  ar: صديق || tr: Ve ==>  0.0
# t(e|f)::  ar: الجنوبي || tr: Ve ==>  0.0
# t(e|f)::  ar: لقبل || tr: Ve ==>  0.0
# t(e|f)::  ar: بها || tr: Ve ==>  0.0
# t(e|f)::  ar: إرهاق || tr: Ve ==>  0.0
# t(e|f)::  ar: الأرمل || tr: Ve ==>  0.0
# t(e|f)::  ar: جامعة || tr: Ve ==>  0.0
# t(e|f)::  ar: مكالمة || tr: Ve ==>  0.0
# t(e|f)::  ar: تعتني || tr: Ve ==>  0.0
# t(e|f)::  ar: عندما || tr: Ve ==>  0.0
# t(e|f)::  ar: من || tr: Ve ==>  0.019803952197016784
# t(e|f)::  ar: بالنسبة || tr: Ve ==>  0.0
# t(e|f)::  ar: زوجتي || tr: Ve ==>  0.0
# t(e|f)::  ar: إمرأة || tr: Ve ==>  0.0
# t(e|f)::  ar: اللأخير || tr: Ve ==>  0.0
# t(e|f)::  ar: هذه || tr: Ve ==>  0.0
# t(e|f)::  ar: في || tr: Ve ==>  0.0777887470356106
# t(e|f)::  ar: الأيام || tr: Ve ==>  0.035808014480616185
# t(e|f)::  ar: مضت || tr: Ve ==>  0.0
# t(e|f)::  ar: بسبب || tr: Ve ==>  0.0
# t(e|f)::  ar: هو || tr: Ve ==>  0.0
# t(e|f)::  ar: ما || tr: Ve ==>  0.014369916197473716
# t(e|f)::  ar: ب || tr: Ve ==>  0.0
# t(e|f)::  ar: السيارة || tr: Ve ==>  0.035808014480616185
# t(e|f)::  ar: القصة || tr: Ve ==>  0.0
# t(e|f)::  ar: بي || tr: Ve ==>  0.0
# t(e|f)::  ar: الذين || tr: Ve ==>  0.01676730414895306
# t(e|f)::  ar: فحينما || tr: Ve ==>  0.0
# t(e|f)::  ar: لشيكاغو || tr: Ve ==>  0.0
# t(e|f)::  ar: أراقب || tr: Ve ==>  0.014369916197473716
# t(e|f)::  ar: وكانت || tr: Ve ==>  0.019803952197016784
# t(e|f)::  ar: سبيل || tr: Ve ==>  0.0
# t(e|f)::  ar: زوج || tr: Ve ==>  0.024532145784054545
# t(e|f)::  ar: موت || tr: Ve ==>  0.0
# t(e|f)::  ar: مخاطر || tr: Ve ==>  0.0
# t(e|f)::  ar: إنكسار || tr: Ve ==>  0.0
# t(e|f)::  ar: حوالي || tr: Ve ==>  0.0
# t(e|f)::  ar: الأول || tr: Ve ==>  0.0
# t(e|f)::  ar: شيكاغو || tr: Ve ==>  0.0
# t(e|f)::  ar: الموت، || tr: Ve ==>  0.01676730414895306
# t(e|f)::  ar: عاماً || tr: Ve ==>  0.0
# t(e|f)::  ar: وشك || tr: Ve ==>  0.01676730414895306
# t(e|f)::  ar: قديمة || tr: Ve ==>  0.0
# t(e|f)::  ar: تتضاعف || tr: Ve ==>  0.0
# t(e|f)::  ar: لأنه || tr: Ve ==>  0.0
# t(e|f)::  ar: فكرة || tr: Ve ==>  0.0
# t(e|f)::  ar: الزوج || tr: Ve ==>  0.0
# t(e|f)::  ar: للناس || tr: Ve ==>  0.014369916197473716
# t(e|f)::  ar: خلال || tr: Ve ==>  0.0
# t(e|f)::  ar: أموت، || tr: Ve ==>  0.0
# t(e|f)::  ar: العلوم || tr: Ve ==>  0.0
# t(e|f)::  ar: على || tr: Ve ==>  0.01676730414895306
# t(e|f)::  ar: لي، || tr: Ve ==>  0.0
# t(e|f)::  ar: فترة || tr: Ve ==>  0.0
# t(e|f)::  ar: الحالة، || tr: Ve ==>  0.0
# t(e|f)::  ar: يحدث || tr: Ve ==>  0.014369916197473716
# t(e|f)::  ar: جداً || tr: Ve ==>  0.0
# t(e|f)::  ar: وقد || tr: Ve ==>  0.012997997391080273
# t(e|f)::  ar: كذلك || tr: Ve ==>  0.0
# t(e|f)::  ar: المنزل || tr: Ve ==>  0.035808014480616185
# t(e|f)::  ar: شاركت || tr: Ve ==>  0.012997997391080273
# t(e|f)::  ar: وكنت || tr: Ve ==>  0.16348573255718518
# t(e|f)::  ar: العناية || tr: Ve ==>  0.06359910973952691
# t(e|f)::  ar: تموت || tr: ben ==>  0.0
# t(e|f)::  ar: طبيباً || tr: ben ==>  0.0
# t(e|f)::  ar: 150 || tr: ben ==>  0.0
# t(e|f)::  ar: إلى || tr: ben ==>  0.05319146701042015
# t(e|f)::  ar: وتلقيت || tr: ben ==>  0.0
# t(e|f)::  ar: أحد || tr: ben ==>  0.05319146701042015
# t(e|f)::  ar: الإجتماعية || tr: ben ==>  0.0
# t(e|f)::  ar: وأسرهم || tr: ben ==>  0.02193193546138129
# t(e|f)::  ar: 15 || tr: ben ==>  0.0
# t(e|f)::  ar: كنت || tr: ben ==>  0.0
# t(e|f)::  ar: القلب." || tr: ben ==>  0.0
# t(e|f)::  ar: العام || tr: ben ==>  0.0
# t(e|f)::  ar: الذي || tr: ben ==>  0.0
# t(e|f)::  ar: نزيلاً || tr: ben ==>  0.0
# t(e|f)::  ar: الإبنة || tr: ben ==>  0.0
# t(e|f)::  ar: تعب || tr: ben ==>  0.0
# t(e|f)::  ar: زوجته || tr: ben ==>  0.0
# t(e|f)::  ar: كانت || tr: ben ==>  0.0
# t(e|f)::  ar: بمريض || tr: ben ==>  0.019308039260412975
# t(e|f)::  ar: بنتها || tr: ben ==>  0.0
# t(e|f)::  ar: لصديقه || tr: ben ==>  0.0
# t(e|f)::  ar: وكان || tr: ben ==>  0.0
# t(e|f)::  ar: " || tr: ben ==>  0.0
# t(e|f)::  ar: أعتني || tr: ben ==>  0.024907203552867033
# t(e|f)::  ar: بالناس || tr: ben ==>  0.024907203552867033
# t(e|f)::  ar: تبدأ || tr: ben ==>  0.0
# t(e|f)::  ar: محبطاً || tr: ben ==>  0.0
# t(e|f)::  ar: الجنون || tr: ben ==>  0.0
# t(e|f)::  ar: لذا، || tr: ben ==>  0.0243937076065728
# t(e|f)::  ar: الزوجين || tr: ben ==>  0.0
# t(e|f)::  ar: كان || tr: ben ==>  0.0
# t(e|f)::  ar: لهذين || tr: ben ==>  0.0
# t(e|f)::  ar: وفي || tr: ben ==>  0.0
# t(e|f)::  ar: بأمها || tr: ben ==>  0.0
# t(e|f)::  ar: يجري || tr: ben ==>  0.0
# t(e|f)::  ar: تأثير || tr: ben ==>  0.0
# t(e|f)::  ar: ومعروفة || tr: ben ==>  0.0
# t(e|f)::  ar: أقود || tr: ben ==>  0.05319146701042015
# t(e|f)::  ar: قبل || tr: ben ==>  0.0
# t(e|f)::  ar: قد || tr: ben ==>  0.0
# t(e|f)::  ar: مرهقة || tr: ben ==>  0.0
# t(e|f)::  ar: "الحزن" || tr: ben ==>  0.0
# t(e|f)::  ar: محدد || tr: ben ==>  0.019308039260412975
# t(e|f)::  ar: الموت || tr: ben ==>  0.0
# t(e|f)::  ar: خلافاً || tr: ben ==>  0.0
# t(e|f)::  ar: مختبري، || tr: ben ==>  0.0
# t(e|f)::  ar: مرضهم || tr: ben ==>  0.0
# t(e|f)::  ar: المثال، || tr: ben ==>  0.0
# t(e|f)::  ar: الجانب || tr: ben ==>  0.0
# t(e|f)::  ar: إتصل || tr: ben ==>  0.0
# t(e|f)::  ar: ترجع || tr: ben ==>  0.0
# t(e|f)::  ar: لما || tr: ben ==>  0.0
# t(e|f)::  ar: أدرس || tr: ben ==>  0.0
# t(e|f)::  ar: صديق || tr: ben ==>  0.0
# t(e|f)::  ar: الجنوبي || tr: ben ==>  0.0
# t(e|f)::  ar: لقبل || tr: ben ==>  0.0
# t(e|f)::  ar: بها || tr: ben ==>  0.0
# t(e|f)::  ar: إرهاق || tr: ben ==>  0.0
# t(e|f)::  ar: الأرمل || tr: ben ==>  0.0
# t(e|f)::  ar: جامعة || tr: ben ==>  0.0
# t(e|f)::  ar: مكالمة || tr: ben ==>  0.0
# t(e|f)::  ar: تعتني || tr: ben ==>  0.0
# t(e|f)::  ar: عندما || tr: ben ==>  0.0
# t(e|f)::  ar: من || tr: ben ==>  0.0
# t(e|f)::  ar: بالنسبة || tr: ben ==>  0.0
# t(e|f)::  ar: زوجتي || tr: ben ==>  0.0243937076065728
# t(e|f)::  ar: إمرأة || tr: ben ==>  0.0
# t(e|f)::  ar: اللأخير || tr: ben ==>  0.0
# t(e|f)::  ar: هذه || tr: ben ==>  0.0
# t(e|f)::  ar: في || tr: ben ==>  0.11555227598465265
# t(e|f)::  ar: الأيام || tr: ben ==>  0.05319146701042015
# t(e|f)::  ar: مضت || tr: ben ==>  0.0
# t(e|f)::  ar: بسبب || tr: ben ==>  0.0
# t(e|f)::  ar: هو || tr: ben ==>  0.0
# t(e|f)::  ar: ما || tr: ben ==>  0.0
# t(e|f)::  ar: ب || tr: ben ==>  0.0
# t(e|f)::  ar: السيارة || tr: ben ==>  0.05319146701042015
# t(e|f)::  ar: القصة || tr: ben ==>  0.0
# t(e|f)::  ar: بي || tr: ben ==>  0.0
# t(e|f)::  ar: الذين || tr: ben ==>  0.024907203552867033
# t(e|f)::  ar: فحينما || tr: ben ==>  0.0243937076065728
# t(e|f)::  ar: لشيكاغو || tr: ben ==>  0.0
# t(e|f)::  ar: أراقب || tr: ben ==>  0.0
# t(e|f)::  ar: وكانت || tr: ben ==>  0.0
# t(e|f)::  ar: سبيل || tr: ben ==>  0.0
# t(e|f)::  ar: زوج || tr: ben ==>  0.0
# t(e|f)::  ar: موت || tr: ben ==>  0.0243937076065728
# t(e|f)::  ar: مخاطر || tr: ben ==>  0.0243937076065728
# t(e|f)::  ar: إنكسار || tr: ben ==>  0.0
# t(e|f)::  ar: حوالي || tr: ben ==>  0.0
# t(e|f)::  ar: الأول || tr: ben ==>  0.0
# t(e|f)::  ar: شيكاغو || tr: ben ==>  0.0
# t(e|f)::  ar: الموت، || tr: ben ==>  0.024907203552867033
# t(e|f)::  ar: عاماً || tr: ben ==>  0.0
# t(e|f)::  ar: وشك || tr: ben ==>  0.024907203552867033
# t(e|f)::  ar: قديمة || tr: ben ==>  0.0
# t(e|f)::  ar: تتضاعف || tr: ben ==>  0.0243937076065728
# t(e|f)::  ar: لأنه || tr: ben ==>  0.0
# t(e|f)::  ar: فكرة || tr: ben ==>  0.0
# t(e|f)::  ar: الزوج || tr: ben ==>  0.0
# t(e|f)::  ar: للناس || tr: ben ==>  0.0
# t(e|f)::  ar: خلال || tr: ben ==>  0.0
# t(e|f)::  ar: أموت، || tr: ben ==>  0.0243937076065728
# t(e|f)::  ar: العلوم || tr: ben ==>  0.0
# t(e|f)::  ar: على || tr: ben ==>  0.024907203552867033
# t(e|f)::  ar: لي، || tr: ben ==>  0.0
# t(e|f)::  ar: فترة || tr: ben ==>  0.0
# t(e|f)::  ar: الحالة، || tr: ben ==>  0.0
# t(e|f)::  ar: يحدث || tr: ben ==>  0.0
# t(e|f)::  ar: جداً || tr: ben ==>  0.0
# t(e|f)::  ar: وقد || tr: ben ==>  0.019308039260412975
# t(e|f)::  ar: كذلك || tr: ben ==>  0.0
# t(e|f)::  ar: المنزل || tr: ben ==>  0.05319146701042015
# t(e|f)::  ar: شاركت || tr: ben ==>  0.019308039260412975
# t(e|f)::  ar: وكنت || tr: ben ==>  0.1272943027862204
# t(e|f)::  ar: العناية || tr: ben ==>  0.018641352100361004
# --------------------------------------------------------------------------
# Source sentence 1 :
# ['بالنسبة', 'لي،', 'تبدأ', 'هذه', 'القصة', 'قبل', 'حوالي', '15', 'عاماً', 'مضت']
# Translation sentence 1 :
# ['Benim', 'için', 'bu', 'hikaye', '15', 'sene', 'önce']
# Alignment:
# 0-1 1-1 2-1 3-2 4-1 5-1 6-1 7-1 9-1
#
# Source sentence 2 :
# ['عندما', 'كنت', 'طبيباً', 'نزيلاً', 'في', 'جامعة', 'شيكاغو']
# Translation sentence 2 :
# ['Chicago', "Üniversitesi'nde", 'bir', 'darülacaze', 'doktoruyken', 'başladı']
# Alignment:
# 0-4 2-4 3-4 5-4 6-4
#
# Source sentence 3 :
# ['وكنت', 'أعتني', 'بالناس', 'الذين', 'على', 'وشك', 'الموت،', 'وأسرهم']
# Translation sentence 3 :
# ['Ve', 'ben', "Chicago'nun", 'güney', 'tarafında,', 'ölmek', 'üzere', 'olan', 'insanlara']
# Alignment:
# 0-8 1-3 2-3 3-3 5-3 6-3 7-8
#
# Source sentence 4 :
# ['في', 'الجانب', 'الجنوبي', 'لشيكاغو']
# Translation sentence 4 :
# ['ve', 'onların', 'ailelerine', 'bakıyordum']
# Alignment:
# 0-3 1-3 2-3 3-3
#
# Source sentence 5 :
# ['وكنت', 'أراقب', 'ما', 'يحدث', 'للناس', 'وأسرهم']
# Translation sentence 5 :
# ['Ve', 'ölümcül', 'hastalıkları', 'süresince', 'bu', 'insanlara', 've', 'onların', 'ailelerine']
# Alignment:
# 0-5 1-2 2-2 3-2 4-2 5-5
#
# Source sentence 6 :
# ['خلال', 'فترة', 'مرضهم', 'اللأخير']
# Translation sentence 6 :
# ['ne', 'olduğunu', 'gözlemliyordum']
# Alignment:
# 0-0 1-0 2-0 3-0
#
# Source sentence 7 :
# ['وفي', 'مختبري،', 'كنت', 'أدرس', 'تأثير', 'الأرمل']
# Translation sentence 7 :
# ['Laboratuvarımda,', 'sosyal', 'bilimlerde', 'çok', 'eski', 'bir', 'fikir', 'olan']
# Alignment:
# 1-4 2-4 3-4 4-4 5-4
#
# Source sentence 8 :
# ['الذي', 'هو', 'فكرة', 'قديمة', 'جداً', 'في', 'العلوم', 'الإجتماعية']
# Translation sentence 8 :
# ['kökleri', '150', 'yıl', 'öncesine', 'kadar', 'giden']
# Alignment:
# 0-3 1-3 2-3 3-3 4-3 6-3 7-3
#
# Source sentence 9 :
# ['ترجع', 'لقبل', '150', 'عاماً']
# Translation sentence 9 :
# ['ve', '"kırık', 'kalpten', 'ölmek"']
# Alignment:
# 0-1 1-1 2-1 3-1
#
# Source sentence 10 :
# ['ومعروفة', 'ب', '"', 'الموت', 'بسبب', 'إنكسار', 'القلب."', '"الحزن"']
# Translation sentence 10 :
# ['olarak', 'bilinen', 'dul', 'kalma', 'etkisini', 'çalışıyordum']
# Alignment:
# 0-4 1-4 2-4 3-4 5-4 6-4 7-4
#
# Source sentence 11 :
# ['لذا،', 'فحينما', 'أموت،', 'تتضاعف', 'مخاطر', 'موت', 'زوجتي']
# Translation sentence 11 :
# ['Buna', 'göre,', 'ben', 'öldüğümde,', 'örneğin', 'ilk', 'yılda']
# Alignment:
# 0-5 1-5 2-5 3-5 4-5 5-5 6-5
#
# Source sentence 12 :
# ['على', 'سبيل', 'المثال،', 'في', 'العام', 'الأول']
# Translation sentence 12 :
# ['karımın', 'ölüm', 'riski', 'ikiye', 'katlanır']
# Alignment:
# 0-0 1-0 2-0 4-0 5-0
#
# Source sentence 13 :
# ['وقد', 'شاركت', 'في', 'العناية', 'بمريض', 'محدد']
# Translation sentence 13 :
# ['Ve', 'ben', 'özel', 'bir', 'hastanın,', 'akıl', 'hastalığından', 'ölmek', 'üzere']
# Alignment:
# 0-4 1-4 3-4 4-4 5-4
#
# Source sentence 14 :
# ['إمرأة', 'كانت', 'تموت', 'بسبب', 'الجنون']
# Translation sentence 14 :
# ['olan', 'bir', 'kadının,', 'bakımıyla', 'ilgileniyordum']
# Alignment:
# 0-2 2-2 3-2 4-2
#
# Source sentence 15 :
# ['وفي', 'هذه', 'الحالة،', 'خلافاً', 'لهذين', 'الزوجين']
# Translation sentence 15 :
# ['Ve,', 'bu', 'durumda,', 'bu', 'çiftten', 'ziyade']
# Alignment:
# 0-0 1-1 2-0 3-0 4-0 5-0
#
# Source sentence 16 :
# ['كانت', 'تعتني', 'بها']
# Translation sentence 16 :
# ['ona', 'kendi', 'kızı']
# Alignment:
# 0-1 1-1 2-1
#
# Source sentence 17 :
# ['بنتها']
# Translation sentence 17 :
# ['bakıyordu']
# Alignment:
# 0-0
#
# Source sentence 18 :
# ['وكانت', 'الإبنة', 'مرهقة', 'من', 'العناية', 'بأمها']
# Translation sentence 18 :
# ['Ve', 'kız', 'annesine', 'bakmaktan', 'yorgun', 'düşmüştü']
# Alignment:
# 0-4 2-4 5-4
#
# Source sentence 19 :
# ['وكان', 'زوج', 'الإبنة']
# Translation sentence 19 :
# ['Ve', 'kızın', 'kocası', 'da']
# Alignment:
# 0-1 1-1 2-1
#
# Source sentence 20 :
# ['كذلك', 'قد', 'تعب']
# Translation sentence 20 :
# ['karısının', 'tükenmişliğinden']
# Alignment:
# 0-0 1-0 2-0
#
# Source sentence 21 :
# ['من', 'إرهاق', 'زوجته']
# Translation sentence 21 :
# ['dolayı', 'hastalanmıştı']
# Alignment:
# 0-1 1-1 2-1
#
# Source sentence 22 :
# ['وكنت', 'أقود', 'السيارة', 'إلى', 'المنزل', 'في', 'أحد', 'الأيام']
# Translation sentence 22 :
# ['Ve', 'ben', 'bir', 'gün', 'eve', 'giderken']
# Alignment:
# 1-5 2-5 3-5 4-5 6-5 7-5
#
# Source sentence 23 :
# ['وتلقيت', 'مكالمة', 'من', 'صديق', 'الزوج']
# Translation sentence 23 :
# ['kocasının', 'arkadaşından', 'bir', 'telefon', 'geldi', 'bana']
# Alignment:
# 0-0 1-0 3-0 4-0
#
# Source sentence 24 :
# ['إتصل', 'بي', 'لأنه', 'كان', 'محبطاً']
# Translation sentence 24 :
# ['arkadaşına', 'olanlardan', 'dolayı']
# Alignment:
# 0-1 1-1 2-1 3-1 4-1
#
# Source sentence 25 :
# ['لما', 'يجري', 'لصديقه']
# Translation sentence 25 :
# ['neşesinin', 'kaçtığından', 'söz', 'ediyordu']
# Alignment:
# 0-2 1-2 2-2

# %% [markdown]
# # Function implementing the IBM1 with EM algorithm model

# %%
def nltk_ibm1():
    print("############### Translation from Turkish to English Using NLTK IBM model 1 ###############")

    # Array containing the pair of sentences, source and translation.
    bitext = []
    # Using AlignedSent for Sentence-aligned parallel corpus.
    bitext.append(AlignedSent(['yol','uzun'], ['الطريق' ,'طويل']))
    #bitext.append(AlignedSent(['yol', 'büyük'], ['الطريق' ,'كبير']))
    bitext.append(AlignedSent(['dağa', 'yol', 'uzun'], ['الطريق', 'إلى' , 'الجبل' , 'طويل']))
    #bitext.append(AlignedSent(['dağa', 'geldim'], ['أتيت', 'إلى', 'الجبل']))
    #bitext.append(AlignedSent(['dağa', 'tırmandım'], ['تسلقت', 'الجبل']))

    myIBM = IBMModel1(bitext, 5) # Passing 2 parameters to the IBMModel1 as the array of Sentence-aligned parallel corpus and number of iterations.
    
 
    # NLTK AlignedSent is a 2-tuple (words_index, mots_index). To extract the required data it needs a for loop for running over the array bitext and 2 inner nested loop for both indexes.
    # Printing t(e|f) for all words and their mots in the other language.
    for i in range(len(bitext)):
        for j in range(len(bitext[i].mots)):
            for k in range(len(bitext[i].words)):
                print("t(e|f):: ", "f:",bitext[i].words[k] ,"||", "e:", bitext[i].mots[j], "==> ", myIBM.translation_table[bitext[i].words[k]][bitext[i].mots[j]])
    print("\n")
 
    # Printing the alignments between the pair of sentences.
    for i in range(len(bitext)):
        print("Source sentence", i + 1, ":")
        print(bitext[i].words)
        
        print("Translation sentence", i + 1, ":")
        print(bitext[i].mots)
        
        print("Alignment:")
        print(bitext[i].alignment, '\n')
